# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/e3/59/35a2892bf09ded9c1bf3804461efe772836a5261ef5dfb4e264ce813ff99/pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.21.0 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 7.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.3 pytz-2023.3 tzdata-2023.3

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/71/3c/3b1981c6a1986adc9ee7db760c0c34ea5b14ac3da9ecfcf1ea2a4ec6c398/numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 6.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.25.2

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=0.25 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from seaborn) (2.0.3)
# Collecting matplotlib!=3.6.1,>=3.1 (from seaborn)
#   Obtaining dependency information for matplotlib!=3.6.1,>=3.1 from https://files.pythonhosted.org/packages/c2/da/a5622266952ab05dc3995d77689cba600e49ea9d6c51d469c077695cb719/matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/aa/55/02c6d24804592b862b38a85c9b3283edc245081390a520ccd11697b6b24f/contourpy-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading contourpy-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/87/61/f50ab3237b0cbf2b0be12274227f912d30f94e2b93fb8bae92c91107eee8/fonttools-4.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading fonttools-4.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached kiwisolver-1.4.4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: packaging>=20.0 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Obtaining dependency information for pillow>=6.2.0 from https://files.pythonhosted.org/packages/3d/36/e78f09d510354977e10102dd811e928666021d9c451e05df962d56477772/Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata
#   Downloading Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/jessica/.pyenv/versions/3.10.6/envs/movie_genre_prediction/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Using cached matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached contourpy-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Downloading fonttools-4.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.6 MB/s eta 0:00:0000:0100:01
# Using cached Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.0 kiwisolver-1.4.4 matplotlib-3.7.2 pillow-10.0.0 pyparsing-3.0.9 seaborn-0.12.2

# %%
from requests import get
from bs4 import BeautifulSoup
from warnings import warn
from time import sleep
from random import randint
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Mystery
URL1 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=mystery&languages=en&sort=user_rating,desc&start='
URL2 = '&explore=genres&ref_=adv_nxt'

# Romance
URL3 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=romance&languages=en&sort=user_rating,desc&start='

# Sci-Fi
URL4 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=sci-fi&languages=en&sort=user_rating,desc&start='

# Sport
URL5 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=sport&languages=en&sort=user_rating,desc&start='

# Thriller
URL6 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=thriller&languages=en&sort=user_rating,desc&start='

# War
URL7 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=war&languages=en&sort=user_rating,desc&start='

# Western
URL8 = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=western&languages=en&sort=user_rating,desc&start='

# %%
# pages = [1,51,101,151,201]
pages = [1]
headers = {'Accept-Language': 'en-US,en;q=0.8'} # If this is not specified, the default language is Mandarin

#initialize empty lists to store the variables scraped
mystery_titles = []
mystery_imdb_ids = []
mystery_genres = []
mystery_imgdata = []

for page in pages:
  
   #get request for sci-fi
   response = get(URL1
                  + str(page)
                  + URL2, headers=headers)
  
   sleep(randint(8,15))
   
   #throw warning for status codes that are not 200
   if response.status_code != 200:
       warn('Request: {}; Status code: {}'.format(requests, response.status_code))

   #parse the content of current iteration of request
   page_html = BeautifulSoup(response.text, 'html.parser')
      
   movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
  
   #extract the 50 movies for that page
   for container in movie_containers:

        #title
        title = container.h3.a.text
        mystery_titles.append(title)

        #imdb_id
        imdb_id = container.find('a')['href'].strip().split('/')[-2]
        mystery_imdb_ids.append(imdb_id)

        #images
        imageDiv = container.find('div', class_ = 'lister-item-image float-left')
        img = imageDiv.find("img", "src", class_ = 'loadlate')
        mystery_imgdata.append(img)
            
        #genre
        genre = container.p.find('span', class_ = 'genre').text.replace("\n", "").rstrip().split(',') # remove the whitespace character, strip, and split to create an array of genres
        mystery_genres.append(genre)

mystery_df = pd.DataFrame({'movie': mystery_titles,
                      'imdb_id': mystery_imdb_ids,
                      'genre': mystery_genres,
                    'image_url':mystery_imgdata}
                          )
mystery_df
# Out:
#                                            movie     imdb_id  \
# 0                                          Se7en   tt0114369
# 1                                 The Green Mile   tt0120689
# 2                                   The Prestige   tt0482571
# 3                             The Usual Suspects   tt0114814
# 4                                         Psycho   tt0054215
# 5                                    Rear Window   tt0047396
# 6                                        Memento   tt0209144
# 7                                 Apocalypse Now   tt0078788
# 8                                           Coco   tt2380307
# 9                    Witness for the Prosecution   tt0051201
# 10                                     Incendies   tt1255953
# 11                                       Vertigo   tt0052357
# 12                                  Citizen Kane   tt0033467
# 13                            North by Northwest   tt0053125
# 14                              Double Indemnity   tt0036775
# 15                                Shutter Island   tt1130884
# 16                                     The Thing   tt0084787
# 17                               The Sixth Sense   tt0167404
# 18                             L.A. Confidential   tt0119488
# 19                                    The Father  tt10272386
# 20                                     Chinatown   tt0071315
# 21                                    Drishyam 2  tt15501640
# 22                                      Drishyam   tt4430212
# 23                                     Andhadhun   tt8108198
# 24                     It's Such a Beautiful Day   tt2396224
# 25                                          Jaws   tt0073195
# 26                                     Prisoners   tt1392214
# 27                                     Gone Girl   tt2267998
# 28  Harry Potter and the Deathly Hallows: Part 2   tt1201607
# 29                            Memories of Murder   tt0353969
# 30                                 The Third Man   tt0041959
# 31                                       Rebecca   tt0032976
# 32                                    Diabolique   tt0046911
# 33                             Blade Runner 2049   tt1856101
# 34                                  Donnie Darko   tt0246578
# 35                                      Zootopia   tt2948356
# 36                                    12 Monkeys   tt0114746
# 37                           The Invisible Guest   tt4857264
# 38                          The Bourne Ultimatum   tt0440963
# 39                             Chungking Express   tt0109424
# 40                            The Maltese Falcon   tt0033870
# 41                           Anatomy of a Murder   tt0052561
# 42                              Infernal Affairs   tt0338564
# 43                                        Sleuth   tt0069281
# 44                                       Arrival   tt2543164
# 45                                    Knives Out   tt8946378
# 46      Harry Potter and the Prisoner of Azkaban   tt0304141
# 47                              Mulholland Drive   tt0166924
# 48                           The Bourne Identity   tt0258463
# 49                      In the Heat of the Night   tt0061811
#
#                                genre image_url
# 0          [Crime,  Drama,  Mystery]        []
# 1          [Crime,  Drama,  Fantasy]        []
# 2         [Drama,  Mystery,  Sci-Fi]        []
# 3          [Crime,  Drama,  Mystery]        []
# 4      [Horror,  Mystery,  Thriller]        []
# 5               [Mystery,  Thriller]        []
# 6               [Mystery,  Thriller]        []
# 7            [Drama,  Mystery,  War]        []
# 8    [Animation,  Adventure,  Drama]        []
# 9          [Crime,  Drama,  Mystery]        []
# 10           [Drama,  Mystery,  War]        []
# 11    [Mystery,  Romance,  Thriller]        []
# 12                 [Drama,  Mystery]        []
# 13    [Action,  Adventure,  Mystery]        []
# 14       [Crime,  Drama,  Film-Noir]        []
# 15              [Mystery,  Thriller]        []
# 16       [Horror,  Mystery,  Sci-Fi]        []
# 17      [Drama,  Mystery,  Thriller]        []
# 18         [Crime,  Drama,  Mystery]        []
# 19                 [Drama,  Mystery]        []
# 20      [Drama,  Mystery,  Thriller]        []
# 21         [Crime,  Drama,  Mystery]        []
# 22         [Crime,  Drama,  Mystery]        []
# 23      [Crime,  Mystery,  Thriller]        []
# 24      [Animation,  Comedy,  Drama]        []
# 25  [Adventure,  Mystery,  Thriller]        []
# 26         [Crime,  Drama,  Mystery]        []
# 27      [Drama,  Mystery,  Thriller]        []
# 28    [Adventure,  Family,  Fantasy]        []
# 29         [Crime,  Drama,  Mystery]        []
# 30  [Film-Noir,  Mystery,  Thriller]        []
# 31     [Drama,  Film-Noir,  Mystery]        []
# 32          [Crime,  Drama,  Horror]        []
# 33        [Action,  Drama,  Mystery]        []
# 34        [Drama,  Mystery,  Sci-Fi]        []
# 35  [Animation,  Adventure,  Comedy]        []
# 36     [Mystery,  Sci-Fi,  Thriller]        []
# 37         [Crime,  Drama,  Mystery]        []
# 38     [Action,  Mystery,  Thriller]        []
# 39          [Comedy,  Crime,  Drama]        []
# 40     [Crime,  Film-Noir,  Mystery]        []
# 41                 [Drama,  Mystery]        []
# 42          [Action,  Crime,  Drama]        []
# 43              [Mystery,  Thriller]        []
# 44        [Drama,  Mystery,  Sci-Fi]        []
# 45          [Comedy,  Crime,  Drama]        []
# 46    [Adventure,  Family,  Fantasy]        []
# 47      [Drama,  Mystery,  Thriller]        []
# 48     [Action,  Mystery,  Thriller]        []
# 49      [Drama,  Mystery,  Thriller]        []

# %%
mystery_imgdata
# Out:
# [<img alt="Se7en" class="loadlate" data-tconst="tt0114369" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOTUwODM5MTctZjczMi00OTk4LTg3NWUtNmVhMTAzNTNjYjcyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Green Mile" class="loadlate" data-tconst="tt0120689" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Prestige" class="loadlate" data-tconst="tt0482571" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Usual Suspects" class="loadlate" data-tconst="tt0114814" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYTViNjMyNmUtNDFkNC00ZDRlLThmMDUtZDU2YWE4NGI2ZjVmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Psycho" class="loadlate" data-tconst="tt0054215" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Rear Window" class="loadlate" data-tconst="tt0047396" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Memento" class="loadlate" data-tconst="tt0209144" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZTcyNjk1MjgtOWI3Mi00YzQwLWI5MTktMzY4ZmI2NDAyNzYzXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Apocalypse Now" class="loadlate" data-tconst="tt0078788" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYmQyNTA1ZGItNjZjMi00NzFlLWEzMWEtNWMwN2Q2MjJhYzEyXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Coco" class="loadlate" data-tconst="tt2380307" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_UY98_CR1,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Witness for the Prosecution" class="loadlate" data-tconst="tt0051201" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNDQwODU5OWYtNDcyNi00MDQ1LThiOGMtZDkwNWJiM2Y3MDg0XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Incendies" class="loadlate" data-tconst="tt1255953" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMWE3MGYzZjktY2Q5Mi00Y2NiLWIyYWUtMmIyNzA3YmZlMGFhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Vertigo" class="loadlate" data-tconst="tt0052357" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYTE4ODEwZDUtNDFjOC00NjAxLWEzYTQtYTI1NGVmZmFlNjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Citizen Kane" class="loadlate" data-tconst="tt0033467" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYjBiOTYxZWItMzdiZi00NjlkLWIzZTYtYmFhZjhiMTljOTdkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="North by Northwest" class="loadlate" data-tconst="tt0053125" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZDA3NDExMTUtMDlhOC00MmQ5LWExZGUtYmI1NGVlZWI4OWNiXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Double Indemnity" class="loadlate" data-tconst="tt0036775" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOTdlNjgyZGUtOTczYi00MDdhLTljZmMtYTEwZmRiOWFkYjRhXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Shutter Island" class="loadlate" data-tconst="tt1130884" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYzhiNDkyNzktNTZmYS00ZTBkLTk2MDAtM2U0YjU1MzgxZjgzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Thing" class="loadlate" data-tconst="tt0084787" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNGViZWZmM2EtNGYzZi00ZDAyLTk3ODMtNzIyZTBjN2Y1NmM1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Sixth Sense" class="loadlate" data-tconst="tt0167404" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMWM4NTFhYjctNzUyNi00NGMwLTk3NTYtMDIyNTZmMzRlYmQyXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="L.A. Confidential" class="loadlate" data-tconst="tt0119488" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMDQ2YzEyZGItYWRhOS00MjBmLTkzMDUtMTdjYzkyMmQxZTJlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Father" class="loadlate" data-tconst="tt10272386" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZGJhNWRiOWQtMjI4OS00ZjcxLTgwMTAtMzQ2ODkxY2JkOTVlXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Chinatown" class="loadlate" data-tconst="tt0071315" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMjJkMDZhYzItZTFhMi00ZGI4LThlNTAtZDNlYmEwNjFkNDYzXkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Drishyam 2" class="loadlate" data-tconst="tt15501640" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYmY2ZDUxNzUtYWZlYy00MThhLWI5NjktZDhjZTU3MDY5YTM3XkEyXkFqcGdeQXVyNTYxMDgzODI@._V1_UY98_CR5,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Drishyam" class="loadlate" data-tconst="tt4430212" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYmJhZmJlYTItZmZlNy00MGY0LTg0ZGMtNWFkYWU5NTA1YTNhXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_UY98_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Andhadhun" class="loadlate" data-tconst="tt8108198" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZWZhMjhhZmYtOTIzOC00MGYzLWI1OGYtM2ZkN2IxNTI4ZWI3XkEyXkFqcGdeQXVyNDAzNDk0MTQ@._V1_UY98_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="It's Such a Beautiful Day" class="loadlate" data-tconst="tt2396224" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BM2Y0YjBiNjAtZjMwZS00ZGY4LWE0MWItMGE5MWI3ZWRmODAyXkEyXkFqcGdeQXVyMjM5NDU5ODY@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Jaws" class="loadlate" data-tconst="tt0073195" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMmVmODY1MzEtYTMwZC00MzNhLWFkNDMtZjAwM2EwODUxZTA5XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Prisoners" class="loadlate" data-tconst="tt1392214" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Gone Girl" class="loadlate" data-tconst="tt2267998" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTk0MDQ3MzAzOV5BMl5BanBnXkFtZTgwNzU1NzE3MjE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Harry Potter and the Deathly Hallows: Part 2" class="loadlate" data-tconst="tt1201607" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMGVmMWNiMDktYjQ0Mi00MWIxLTk0N2UtN2ZlYTdkN2IzNDNlXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Memories of Murder" class="loadlate" data-tconst="tt0353969" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOGViNTg4YTktYTQ2Ni00MTU0LTk2NWUtMTI4OTc1YTM0NzQ2XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Third Man" class="loadlate" data-tconst="tt0041959" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYjE2OTdhMWUtOGJlMy00ZDViLWIzZjgtYjZkZGZmMDZjYmEyXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Rebecca" class="loadlate" data-tconst="tt0032976" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYTcxYWExOTMtMWFmYy00ZjgzLWI0YjktNWEzYzJkZTg0NDdmL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UY98_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Diabolique" class="loadlate" data-tconst="tt0046911" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYzkxYjA0YTYtYzU4NS00MjgzLWI3YjQtMmMzMzE4NzA1YmQ3XkEyXkFqcGdeQXVyMTA0MTM5NjI2._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Blade Runner 2049" class="loadlate" data-tconst="tt1856101" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNzA1Njg4NzYxOV5BMl5BanBnXkFtZTgwODk5NjU3MzI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Donnie Darko" class="loadlate" data-tconst="tt0246578" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZjZlZDlkYTktMmU1My00ZDBiLWFlNjEtYTBhNjVhOTM4ZjJjXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Zootopia" class="loadlate" data-tconst="tt2948356" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOTMyMjEyNzIzMV5BMl5BanBnXkFtZTgwNzIyNjU0NzE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="12 Monkeys" class="loadlate" data-tconst="tt0114746" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BN2Y2OWU4MWMtNmIyMy00YzMyLWI0Y2ItMTcyZDc3MTdmZDU4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Invisible Guest" class="loadlate" data-tconst="tt4857264" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BOTEwYTkzMTMtODEzNC00YWM2LTgxNDMtZWNkNTQzNDVjMWQ2L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMDY4NTQ1MA@@._V1_UY98_CR1,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Bourne Ultimatum" class="loadlate" data-tconst="tt0440963" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNGNiNmU2YTMtZmU4OS00MjM0LTlmYWUtMjVlYjAzYjE2N2RjXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Chungking Express" class="loadlate" data-tconst="tt0109424" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BNmEyYzUwYTMtYTNiNS00YWE4LWIxZTEtNTVlZDBlNmQ4NGE2XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Maltese Falcon" class="loadlate" data-tconst="tt0033870" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZjIwNGM1ZTUtOThjYS00NDdiLTk2ZDYtNGY5YjJkNzliM2JjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Anatomy of a Murder" class="loadlate" data-tconst="tt0052561" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMzM0MzE2ZTAtZTBjZS00MTk5LTg5OTEtNjNmYmQ5NzU2OTUyXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Infernal Affairs" class="loadlate" data-tconst="tt0338564" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZWM1MTdhM2YtNjgwZS00YjQ3LTk3NTQtMzQ1NDE3YzZlODFlXkEyXkFqcGdeQXVyMTI3ODAyMzE2._V1_UY98_CR4,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Sleuth" class="loadlate" data-tconst="tt0069281" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BM2EzZmFmMmItODY3Zi00NjdjLWE0MTYtZWQ3MGIyM2M4YjZhXkEyXkFqcGdeQXVyMzg2MzE2OTE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Arrival" class="loadlate" data-tconst="tt2543164" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTExMzU0ODcxNDheQTJeQWpwZ15BbWU4MDE1OTI4MzAy._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Knives Out" class="loadlate" data-tconst="tt8946378" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMGUwZjliMTAtNzAxZi00MWNiLWE2NzgtZGUxMGQxZjhhNDRiXkEyXkFqcGdeQXVyNjU1NzU3MzE@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Harry Potter and the Prisoner of Azkaban" class="loadlate" data-tconst="tt0304141" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTY4NTIwODg0N15BMl5BanBnXkFtZTcwOTc0MjEzMw@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="Mulholland Drive" class="loadlate" data-tconst="tt0166924" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BYTRiMzg4NDItNTc3Zi00NjBjLTgwOWYtOGZjMTFmNGU4ODY4XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="The Bourne Identity" class="loadlate" data-tconst="tt0258463" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BM2JkNGU0ZGMtZjVjNS00NjgyLWEyOWYtZmRmZGQyN2IxZjA2XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>,
#  <img alt="In the Heat of the Night" class="loadlate" data-tconst="tt0061811" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZDM1MTM4NGYtZDNjYy00ZDA5LTk4NTctYzg2OTVjZGRiODY3XkEyXkFqcGdeQXVyMTUzMDUzNTI3._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="67"/>]

# %%
pages = [1,51,101,151,201]
headers = {'Accept-Language': 'en-US,en;q=0.8'} # If this is not specified, the default language is Mandarin

#initialize empty lists to store the variables scraped
romance_titles = []
romance_imdb_ids = []
romance_genres = []
romance_imgdata = []

for page in pages:
  
   #get request for sci-fi
   response = get(URL3
                  + str(page)
                  + URL2, headers=headers)
  
   sleep(randint(8,15))
   
   #throw warning for status codes that are not 200
   if response.status_code != 200:
       warn('Request: {}; Status code: {}'.format(requests, response.status_code))

   #parse the content of current iteration of request
   page_html = BeautifulSoup(response.text, 'html.parser')
      
   movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
  
   #extract the 50 movies for that page
   for container in movie_containers:

        #title
        title = container.h3.a.text
        romance_titles.append(title)

        #imdb_id
        imdb_id = container.find('a')['href'].strip().split('/')[-2]
        romance_imdb_ids.append(imdb_id)

        #images
        imageDiv = container.find('div', attrs={'class':'lister-item-image float-left'})
        img = imageDiv.a.img('loadlate')
        romance_imgdata.append(img)
            
        #genre
        genre = container.p.find('span', class_ = 'genre').text.replace("\n", "").rstrip().split(',') # remove the whitespace character, strip, and split to create an array of genres
        romance_genres.append(genre)

romance_df = pd.DataFrame({'movie': romance_titles,
                      'imdb_id': romance_imdb_ids,
                      'genre': romance_genres}
                          )
romance_df
# Out:
#                                    movie    imdb_id  \
# 0    Ramayana: The Legend of Prince Rama  tt0259534
# 1                           Forrest Gump  tt0109830
# 2                      Life Is Beautiful  tt0118799
# 3                  It's a Wonderful Life  tt0038650
# 4                             Casablanca  tt0034583
# ..                                   ...        ...
# 245                       A Royal Affair  tt1276419
# 246                           Robin Hood  tt0070608
# 247                                Waves  tt8652728
# 248                        Lust, Caution  tt0808357
# 249                     The Time Machine  tt0054387
#
#                                 genre
# 0    [Animation,  Action,  Adventure]
# 1                   [Drama,  Romance]
# 2          [Comedy,  Drama,  Romance]
# 3          [Drama,  Family,  Fantasy]
# 4             [Drama,  Romance,  War]
# ..                                ...
# 245     [Biography,  Drama,  History]
# 246  [Animation,  Adventure,  Comedy]
# 247         [Drama,  Romance,  Sport]
# 248       [Drama,  History,  Romance]
# 249    [Adventure,  Romance,  Sci-Fi]
#
# [250 rows x 3 columns]
